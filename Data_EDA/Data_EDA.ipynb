# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/SarthakPratik/Desktop/ds_comp_pro/Data_Cleaning/salary_data_cleaned.csv')

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                   Research Scientist
# 9                                       Data Scientist
# 10                                      Data Scientist
# 11                                      Data Scientist
# 12                   Staff Data Scientist - Technology
# 13                                        Data Analyst
# 14                                      Data Scientist
# 15                                     Data Engineer I
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'Min_salary', 'Max_salary', 'Avg_salary',
#        'Comp_txt', 'Age', 'job_state', 'python_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

# %%
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_Simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_Simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# mle                22
# manager            22
# director           14
# Name: job_Simp, dtype: int64

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
df['Seniority'] = df['Job Title'].apply(seniority)

# %%
df.Seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: Seniority, dtype: int64

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# WA     21
# NC     21
# NJ     17
# FL     16
# OH     14
# TN     13
# CO     11
# DC     11
# IN     10
# WI     10
# UT     10
# AZ      9
# MO      9
# AL      8
# GA      6
# KY      6
# DE      6
# MI      6
# CT      5
# IA      5
# OR      4
# LA      4
# NE      4
# KS      3
# NM      3
# MN      2
# ID      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df.desc_len
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
df['nump_comp'] = df.Competitors.apply(lambda x: len(x.split(',')) if x!= '-1' else 0)

# %%
df.nump_comp
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: nump_comp, Length: 742, dtype: int64

# %%
df['Min_salary'] = df.apply(lambda x: x.Min_salary*2 if x.hourly ==1 else x.Min_salary, axis=1)
df['Max_salary'] = df.apply(lambda x: x.Max_salary*2 if x.hourly ==1 else x.Max_salary,axis=1)

# %%
df[df.hourly ==1][['Min_salary','Max_salary']]
# Out:
#      Min_salary  Max_salary
# 165          34          48
# 177          42          68
# 197          36          50
# 202          42          68
# 210          30          50
# 246          34          48
# 271          42          68
# 337          36          50
# 345          48          78
# 357          42          68
# 363          50          56
# 408          42          58
# 409          20          34
# 492          36          50
# 509          48          78
# 533          42          68
# 542          50          56
# 617          42          58
# 618          20          34
# 645          54          94
# 666          36          50
# 682          48          78
# 711          42          68
# 724          50          56

# %%
df['Comp_txt'] = df.Comp_txt.apply(lambda x: x.replace('\n',''))
df.Comp_txt
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: Comp_txt, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  Min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        Max_salary  Avg_salary         Age   python_yn      desc_len  \
# count  742.000000  742.000000  742.000000  742.000000    742.000000
# mean   128.149596  100.626011   46.591644    0.528302   3869.545822
# std     45.220324   38.855948   53.778815    0.499535   1521.495868
# ...

# %%
df[df.Age == df.Age.max()]['Comp_txt']
# Out:
# 277    Sotheby's
# Name: Comp_txt, dtype: object

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.Age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.Avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Age'])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(y='Age',data=df,palette='winter')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df['Age'].iplot(kind='box',bins=30,color='green')
# Out:
# <div>                            <div id="99f94718-6d8d-4a42-98de-e60bc7664376" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['Avg_salary'].iplot(kind='box',bins=30,color='green')
# Out:
# <div>                            <div id="fe2c338d-4c0a-44db-ba5f-7e88a0150dde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['Rating'].iplot(kind='box',bins=30,color='green')
# Out:
# <div>                            <div id="d5c95715-ce2c-4ef0-93b1-99c8d7fa9c87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['desc_len'].iplot(kind='box',bins=30,color='green')
# Out:
# <div>                            <div id="ac55cd8e-3006-4a00-bd65-e5be2610952e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
corr_m =  df[['Age','Avg_salary','desc_len','Rating','nump_comp']].corr()
corr_m
# Out:
#                  Age  Avg_salary  desc_len    Rating  nump_comp
# Age         1.000000    0.019655  0.163911  0.021655   0.126687
# Avg_salary  0.019655    1.000000  0.078808  0.013492   0.093813
# desc_len    0.163911    0.078808  1.000000 -0.012281   0.104620
# Rating      0.021655    0.013492 -0.012281  1.000000   0.027190
# nump_comp   0.126687    0.093813  0.104620  0.027190   1.000000

# %%
sns.heatmap(corr_m,vmax=.2, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'Comp_txt', 'job_state', 'python_yn','job_Simp', 'Seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for Comp_txt: total = 343
# graph for job_state: total = 37
# graph for python_yn: total = 2
# graph for job_Simp: total = 7
# graph for Seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','Comp_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for Comp_txt: total = 20

# %%
pd.pivot_table(df,index='job_Simp',values='Avg_salary')
# Out:
#                 Avg_salary
# job_Simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df, index = ['job_Simp','Seniority'], values = 'Avg_salary')
# Out:
#                           Avg_salary
# job_Simp       Seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.pivot_table(df, index = ['job_state','job_Simp'], values = 'Avg_salary').sort_values('job_state', ascending = True)
# Out:
#                           Avg_salary
# job_state job_Simp
# AL        analyst          62.200000
#           data engineer    65.000000
#           na               43.750000
# AZ        analyst          55.000000
#           data engineer    79.500000
#           data scientist   69.500000
#           na              124.500000
# CA        mle             177.300000
#           manager          80.611111
#           na               99.907407
#           data engineer   129.540000
#           analyst          85.250000
#           data scientist  142.522059
# CO        analyst          29.500000
#           data engineer    99.000000
#           data scientist  108.666667
#           mle             100.500000
#           na               31.500000
# CT        data scientist   84.000000
#           na               62.500000
# DC        analyst          63.500000
#           data engineer    85.000000
#           data scientist  149.000000
# DE        na               27.500000
# ...

# %%
## To View Full Dataframe
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df[df.job_Simp == 'data scientist'], index = 'job_state', values = 'Avg_salary').sort_values('Avg_salary', ascending = False)
# Out:
#            Avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'nump_comp', 'hourly', 'employer_provided', 'python_yn','Type of ownership','Avg_salary']]

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'Avg_salary')
# Out:
# python_yn                                  0           1
# Revenue
# $1 to $2 billion (USD)             80.093750  113.420455
# $1 to $5 million (USD)            102.000000  121.785714
# $10 to $25 million (USD)           80.875000  119.843750
# $10+ billion (USD)                102.393939  129.698276
# $100 to $500 million (USD)         67.319149  100.068182
# $2 to $5 billion (USD)             79.000000  106.886364
# $25 to $50 million (USD)           79.166667   88.343750
# $5 to $10 billion (USD)            74.888889  111.550000
# $5 to $10 million (USD)           112.111111  140.111111
# $50 to $100 million (USD)          74.071429  122.820000
# $500 million to $1 billion (USD)   79.224138   95.035714
# -1                                117.500000         NaN
# Less than $1 million (USD)         98.500000  112.000000
# Unknown / Non-Applicable           95.806452  111.500000

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'Avg_salary', aggfunc = 'count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
